# %% [markdown]
# ### Correr el script de carga inicial

# %%
# %run BiblioIA.ipynb

# %% [markdown]
# ### 1- ¿Cuáles son los 5 libros más prestados este año?

# %%
preguntar("¿Cuáles son los 5 libros más prestados este año?")

# %% [markdown]
# ### 2- ¿Qué socios tienen préstamos vencidos en este momento?

# %%
preguntar("¿Qué socios tienen préstamos vencidos en este momento?")

# %% [markdown]
# ### 3- ¿Cuántos ejemplares disponibles hay del libro con ISBN 9780747532699?

# %%
preguntar("¿Cuántos ejemplares disponibles hay del libro con ISBN 9780747532699?")

# %% [markdown]
# ### 4- ¿Qué libros de ciencia ficción están disponibles para prestar?

# %%
preguntar("¿Qué libros de ciencia ficción están disponibles para prestar?")

# %% [markdown]
# ### 5- ¿Cuál es el historial de préstamos del socio con DNI 36234567?

# %%
preguntar("¿Cuál es el historial de préstamos del socio con DNI 36234567?")

# %% [markdown]
# ### 6- ¿Qué autores tienen más de 3 libros en la biblioteca?

# %%
preguntar("¿Qué autores tienen más de 3 libros en la biblioteca?")

# %% [markdown]
# ### 7- ¿Cuántas sanciones se generaron en el último mes?

# %%
preguntar("¿Cuántas sanciones se generaron en el último mes?")

# %% [markdown]
# ### 8- ¿Cuantos ejemplares de cada libro hay prestados actualmente y cuantos disponibles?

# %%
preguntar("¿Cuantos ejemplares de cada libro hay prestados actualmente y cuantos disponibles?")

# %% [markdown]
# ### 9- ¿Que socios tienen sanciones activas de tipo 3?

# %%
preguntar("¿Que socios tienen sanciones activas de tipo 3?")

# %% [markdown]
# ### 10- Dame los nombres de los socios que tengan sanciones activas con libros del genero ciencia ficcion

# %%
preguntar("Dame los nombres de los socios que tengan sanciones activas con libros del genero ciencia ficcion")
